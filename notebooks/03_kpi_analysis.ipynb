# %% [markdown]
# # TMDB Movie KPI Analysis & Performance Metrics
#
# This notebook analyzes cleaned movie data to identify top performers and generate insights.
#
# ## Objectives
# 1. Identify best/worst performing movies by revenue, budget, profit, ROI
# 2. Find most voted, highest/lowest rated, and most popular movies
# 3. Execute advanced search queries (Sci-Fi Action + Bruce Willis, Uma + Tarantino)
# 4. Compare franchise vs standalone movie performance
# 5. Identify most successful franchises and directors
#
# ## Setup

# %%
# Import required libraries
import sys
import os
from pathlib import Path
import pandas as pd
import numpy as np

# Add project root to path and set working directory
project_root = Path.cwd().parent
sys.path.append(str(project_root))
os.chdir(str(project_root))

from src.analytics.kpi_calculator import *
from src.analytics.filters import *
from src.analytics.aggregators import *
from src.utils.helpers import load_config, setup_logging

# Setup logger for notebook
logger = setup_logging(module_name='kpi_notebook')
logger.info("✓ Imports successful")
# Out:
# 2025-12-10 08:47:26 - kpi_notebook - INFO - ✓ Imports successful

# %% [markdown]
# ## 1. Load Configuration and Data
#
# Load the cleaned data from Step 2 (Data Cleaning & Preprocessing).

# %%
# Load configuration
config = load_config('config/config.yaml')
processed_path = Path(config['paths']['processed_data'])

# Load cleaned data from Step 2
df = pd.read_parquet(processed_path / 'movies_cleaned.parquet')

logger.info(f"Loaded {len(df)} movies")
logger.info(f"Columns: {list(df.columns)}")
logger.info(f"Memory usage: {df.memory_usage(deep=True).sum() / 1024**2:.2f} MB")

# Display first few rows
df.head()
# Out:
# 2025-12-10 08:47:26 - kpi_notebook - INFO - Loaded 18 movies
# 2025-12-10 08:47:26 - kpi_notebook - INFO - Columns: ['id', 'title', 'tagline', 'release_date', 'genres', 'collection_name', 'original_language', 'budget_musd', 'revenue_musd', 'production_companies', 'production_countries', 'vote_count', 'vote_average', 'popularity', 'runtime', 'overview', 'spoken_languages', 'poster_path', 'cast', 'cast_size', 'director', 'crew_size']
# 2025-12-10 08:47:26 - kpi_notebook - INFO - Memory usage: 0.02 MB
#        id                                         title  \
# 0  109445                                        Frozen
# 1   12445  Harry Potter and the Deathly Hallows: Part 2
# 2  135397                                Jurassic World
# 3  140607                  Star Wars: The Force Awakens
# 4  168259                                     Furious 7
#
#                                              tagline release_date  \
# 0  Only the act of true love will thaw a frozen h...   2013-11-20
# 1                                       It all ends.   2011-07-12
# 2                                  The park is open.   2015-06-06
# 3                      Every generation has a story.   2015-12-15
# 4                               Vengeance hits home.   2015-04-01
#
#                                       genres  \
# 0         Animation|Family|Adventure|Fantasy
# 1                          Adventure|Fantasy
# 2  Action|Adventure|Science Fiction|Thriller
# 3           Adventure|Action|Science Fiction
# 4                      Action|Crime|Thriller
#
#                        collection_name original_language  budget_musd  \
# 0                    Frozen Collection                en        150.0
# 1              Harry Potter Collection                en        125.0
# 2             Jurassic Park Collection                en        150.0
# 3                 Star Wars Collection                en        245.0
# 4  The Fast and the Furious Collection                en        190.0
#
#    revenue_musd                               production_companies  ...  \
# 0   1274.219009                      Walt Disney Animation Studios  ...
# 1   1341.511219                 Warner Bros. Pictures|Heyday Films  ...
# 2   1671.537444  Amblin Entertainment|Universal Pictures|Legend...  ...
# 3   2068.223624                           Lucasfilm Ltd.|Bad Robot  ...
# 4   1515.400000          Original Film|One Race|Universal Pictures  ...
#
#   vote_average  popularity  runtime  \
# 0        7.250     18.2770      102
# 1        8.084     17.3221      130
# 2        6.699      9.3758      124
# 3        7.300      7.5842      136
# 4        7.223     17.1859      139
#
#                                             overview  \
# 0  Young princess Anna of Arendelle dreams about ...
# 1  Harry, Ron and Hermione continue their quest t...
# 2  Twenty-two years after the events of Jurassic ...
# 3  Thirty years after defeating the Galactic Empi...
# 4  Deckard Shaw seeks revenge against Dominic Tor...
#
#                   spoken_languages                       poster_path  \
# 0                          English  /itAKcobTYGpYT8Phwjd8c9hleTo.jpg
# 1                          English  /c54HpQmuwXjHq2C9wmoACjxoom3.jpg
# 2                          English  /rhr4y79GpxQF9IsfJItRXVaoGs4.jpg
# 3                          English  /wqnLdwVXoBjKibFRR5U3y0aDUhs.jpg
# 4  العربية|English|Español|ภาษาไทย  /ktofZ9Htrjiy0P6LEowsDaxd3Ri.jpg
#
#                                                 cast cast_size  \
# 0  Idina Menzel|Kristen Bell|Jonathan Groff|Josh ...        60
# 1  Daniel Radcliffe|Emma Watson|Rupert Grint|Ralp...       105
# 2  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...        53
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...       183
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...        49
#
#           director  crew_size
# 0       Chris Buck        285
# 1      David Yates        159
# 2  Colin Trevorrow        426
# 3      J.J. Abrams        262
# 4        James Wan        227
#
# [5 rows x 22 columns]

# %% [markdown]
# ## 2. Best/Worst Performing Movies - Revenue
#
# Identify movies with the highest and lowest revenue.

# %%
# Highest revenue movies
logger.info("="*60)
logger.info("TOP 10 MOVIES BY REVENUE")
logger.info("="*60)

top_revenue = get_top_by_revenue(df, top_n=10)
top_revenue
# Out:
# 2025-12-10 08:47:26 - kpi_notebook - INFO - ============================================================
# 2025-12-10 08:47:26 - kpi_notebook - INFO - TOP 10 MOVIES BY REVENUE
# 2025-12-10 08:47:26 - kpi_notebook - INFO - ============================================================
#       rank                         title  revenue_musd  release_year  \
# rank
# 1        1                        Avatar   2923.706026          2009
# 2        2             Avengers: Endgame   2799.439100          2019
# 3        3                       Titanic   2264.162353          1997
# 4        4  Star Wars: The Force Awakens   2068.223624          2015
# 5        5        Avengers: Infinity War   2052.415039          2018
# 6        6                Jurassic World   1671.537444          2015
# 7        7                 The Lion King   1662.020819          2019
# 8        8                  The Avengers   1518.815515          2012
# 9        9                     Furious 7   1515.400000          2015
# 10      10                     Frozen II   1453.683476          2019
#
#       budget_musd
# rank
# 1           237.0
# 2           356.0
# 3           200.0
# 4           245.0
# 5           300.0
# 6           150.0
# 7           260.0
# 8           220.0
# 9           190.0
# 10          150.0

# %%
# Lowest revenue movies
logger.info("\n" + "="*60)
logger.info("BOTTOM 10 MOVIES BY REVENUE")
logger.info("="*60)

bottom_revenue = get_bottom_by_revenue(df, top_n=10)
bottom_revenue
# Out:
# 2025-12-10 08:47:26 - kpi_notebook - INFO -
# ============================================================
# 2025-12-10 08:47:26 - kpi_notebook - INFO - BOTTOM 10 MOVIES BY REVENUE
# 2025-12-10 08:47:26 - kpi_notebook - INFO - ============================================================
#       rank                                         title  revenue_musd  \
# rank
# 1        1                                 Incredibles 2   1243.225667
# 2        2                          Beauty and the Beast   1266.115964
# 3        3                                        Frozen   1274.219009
# 4        4                Jurassic World: Fallen Kingdom   1310.469037
# 5        5                      Star Wars: The Last Jedi   1332.698830
# 6        6  Harry Potter and the Deathly Hallows: Part 2   1341.511219
# 7        7                                 Black Panther   1349.926083
# 8        8                       Avengers: Age of Ultron   1405.403694
# 9        9                                     Frozen II   1453.683476
# 10      10                                     Furious 7   1515.400000
#
#       release_year  budget_musd
# rank
# 1             2018        200.0
# 2             2017        160.0
# 3             2013        150.0
# 4             2018        170.0
# 5             2017        300.0
# 6             2011        125.0
# 7             2018        200.0
# 8             2015        235.0
# 9             2019        150.0
# 10            2015        190.0

# %% [markdown]
# ## 3. Best/Worst Performing Movies - Budget
#
# Identify movies with the highest and lowest production budgets.

# %%
# Highest budget movies
logger.info("="*60)
logger.info("TOP 10 MOVIES BY BUDGET")
logger.info("="*60)

top_budget = get_top_by_budget(df, top_n=10)
top_budget
# Out:
# 2025-12-10 08:47:26 - kpi_notebook - INFO - ============================================================
# 2025-12-10 08:47:26 - kpi_notebook - INFO - TOP 10 MOVIES BY BUDGET
# 2025-12-10 08:47:26 - kpi_notebook - INFO - ============================================================
#       rank                         title  budget_musd  release_year  \
# rank
# 1        1             Avengers: Endgame        356.0          2019
# 2        2      Star Wars: The Last Jedi        300.0          2017
# 3        3        Avengers: Infinity War        300.0          2018
# 4        4                 The Lion King        260.0          2019
# 5        5  Star Wars: The Force Awakens        245.0          2015
# 6        6                        Avatar        237.0          2009
# 7        7       Avengers: Age of Ultron        235.0          2015
# 8        8                  The Avengers        220.0          2012
# 9        9                       Titanic        200.0          1997
# 10      10                 Incredibles 2        200.0          2018
#
#       revenue_musd
# rank
# 1      2799.439100
# 2      1332.698830
# 3      2052.415039
# 4      1662.020819
# 5      2068.223624
# 6      2923.706026
# 7      1405.403694
# 8      1518.815515
# 9      2264.162353
# 10     1243.225667

# %%
# Lowest budget movies
logger.info("\n" + "="*60)
logger.info("BOTTOM 10 MOVIES BY BUDGET")
logger.info("="*60)

bottom_budget = get_bottom_by_budget(df, top_n=10)
bottom_budget
# Out:
# 2025-12-10 08:47:26 - kpi_notebook - INFO -
# ============================================================
# 2025-12-10 08:47:26 - kpi_notebook - INFO - BOTTOM 10 MOVIES BY BUDGET
# 2025-12-10 08:47:26 - kpi_notebook - INFO - ============================================================
#       rank                                         title  budget_musd  \
# rank
# 1        1  Harry Potter and the Deathly Hallows: Part 2        125.0
# 2        2                                        Frozen        150.0
# 3        3                                Jurassic World        150.0
# 4        4                                     Frozen II        150.0
# 5        5                          Beauty and the Beast        160.0
# 6        6                Jurassic World: Fallen Kingdom        170.0
# 7        7                                     Furious 7        190.0
# 8        8                                 Incredibles 2        200.0
# 9        9                                 Black Panther        200.0
# 10      10                                       Titanic        200.0
#
#       release_year  revenue_musd
# rank
# 1             2011   1341.511219
# 2             2013   1274.219009
# 3             2015   1671.537444
# 4             2019   1453.683476
# 5             2017   1266.115964
# 6             2018   1310.469037
# 7             2015   1515.400000
# 8             2018   1243.225667
# 9             2018   1349.926083
# 10            1997   2264.162353

# %% [markdown]
# ## 4. Best/Worst Performing Movies - Profit
#
# Identify movies with the highest and lowest profit (Revenue - Budget).

# %%
# Highest profit movies
logger.info("="*60)
logger.info("TOP 10 MOVIES BY PROFIT")
logger.info("="*60)

top_profit = get_top_by_profit(df, top_n=10)
top_profit
# Out:
# 2025-12-10 08:47:26 - kpi_notebook - INFO - ============================================================
# 2025-12-10 08:47:26 - kpi_notebook - INFO - TOP 10 MOVIES BY PROFIT
# 2025-12-10 08:47:26 - kpi_notebook - INFO - ============================================================
#       rank                         title  profit_musd  release_year  \
# rank
# 1        1                        Avatar  2686.706026          2009
# 2        2             Avengers: Endgame  2443.439100          2019
# 3        3                       Titanic  2064.162353          1997
# 4        4  Star Wars: The Force Awakens  1823.223624          2015
# 5        5        Avengers: Infinity War  1752.415039          2018
# 6        6                Jurassic World  1521.537444          2015
# 7        7                 The Lion King  1402.020819          2019
# 8        8                     Furious 7  1325.400000          2015
# 9        9                     Frozen II  1303.683476          2019
# 10      10                  The Avengers  1298.815515          2012
#
#       budget_musd  revenue_musd
# rank
# 1           237.0   2923.706026
# 2           356.0   2799.439100
# 3           200.0   2264.162353
# 4           245.0   2068.223624
# 5           300.0   2052.415039
# 6           150.0   1671.537444
# 7           260.0   1662.020819
# 8           190.0   1515.400000
# 9           150.0   1453.683476
# 10          220.0   1518.815515

# %%
# Lowest profit movies
logger.info("\n" + "="*60)
logger.info("BOTTOM 10 MOVIES BY PROFIT")
logger.info("="*60)

bottom_profit = get_bottom_by_profit(df, top_n=10)
bottom_profit
# Out:
# 2025-12-10 08:47:26 - kpi_notebook - INFO -
# ============================================================
# 2025-12-10 08:47:26 - kpi_notebook - INFO - BOTTOM 10 MOVIES BY PROFIT
# 2025-12-10 08:47:26 - kpi_notebook - INFO - ============================================================
#       rank                                         title  profit_musd  \
# rank
# 1        1                      Star Wars: The Last Jedi  1032.698830
# 2        2                                 Incredibles 2  1043.225667
# 3        3                          Beauty and the Beast  1106.115964
# 4        4                                        Frozen  1124.219009
# 5        5                Jurassic World: Fallen Kingdom  1140.469037
# 6        6                                 Black Panther  1149.926083
# 7        7                       Avengers: Age of Ultron  1170.403694
# 8        8  Harry Potter and the Deathly Hallows: Part 2  1216.511219
# 9        9                                  The Avengers  1298.815515
# 10      10                                     Frozen II  1303.683476
#
#       release_year  budget_musd  revenue_musd
# rank
# 1             2017        300.0   1332.698830
# 2             2018        200.0   1243.225667
# 3             2017        160.0   1266.115964
# 4             2013        150.0   1274.219009
# 5             2018        170.0   1310.469037
# 6             2018        200.0   1349.926083
# 7             2015        235.0   1405.403694
# 8             2011        125.0   1341.511219
# 9             2012        220.0   1518.815515
# 10            2019        150.0   1453.683476

# %% [markdown]
# ## 5. Best/Worst Performing Movies - ROI
#
# Calculate Return on Investment (ROI) for movies with budget >= $10M.
#
# ROI = (Revenue - Budget) / Budget × 100

# %%
# Highest ROI (budget >= $10M)
logger.info("="*60)
logger.info("TOP 10 MOVIES BY ROI (Budget >= $10M)")
logger.info("="*60)

top_roi = get_top_by_roi(df, top_n=10)
top_roi
# Out:
# 2025-12-10 08:47:26 - kpi_notebook - INFO - ============================================================
# 2025-12-10 08:47:26 - kpi_notebook - INFO - TOP 10 MOVIES BY ROI (Budget >= $10M)
# 2025-12-10 08:47:26 - kpi_notebook - INFO - ============================================================
#       rank                                         title          roi  \
# rank
# 1        1                                        Avatar  1133.631235
# 2        2                                       Titanic  1032.081177
# 3        3                                Jurassic World  1014.358296
# 4        4  Harry Potter and the Deathly Hallows: Part 2   973.208975
# 5        5                                     Frozen II   869.122317
# 6        6                                        Frozen   749.479339
# 7        7                  Star Wars: The Force Awakens   744.172908
# 8        8                                     Furious 7   697.578947
# 9        9                          Beauty and the Beast   691.322478
# 10      10                             Avengers: Endgame   686.359298
#
#       release_year  budget_musd  revenue_musd
# rank
# 1             2009        237.0   2923.706026
# 2             1997        200.0   2264.162353
# 3             2015        150.0   1671.537444
# 4             2011        125.0   1341.511219
# 5             2019        150.0   1453.683476
# 6             2013        150.0   1274.219009
# 7             2015        245.0   2068.223624
# 8             2015        190.0   1515.400000
# 9             2017        160.0   1266.115964
# 10            2019        356.0   2799.439100

# %%
# Lowest ROI (budget >= $10M)
logger.info("\n" + "="*60)
logger.info("BOTTOM 10 MOVIES BY ROI (Budget >= $10M)")
logger.info("="*60)

bottom_roi = get_bottom_by_roi(df, top_n=10)
bottom_roi
# Out:
# 2025-12-10 08:47:26 - kpi_notebook - INFO -
# ============================================================
# 2025-12-10 08:47:26 - kpi_notebook - INFO - BOTTOM 10 MOVIES BY ROI (Budget >= $10M)
# 2025-12-10 08:47:26 - kpi_notebook - INFO - ============================================================
#       rank                           title         roi  release_year  \
# rank
# 1        1        Star Wars: The Last Jedi  344.232943          2017
# 2        2         Avengers: Age of Ultron  498.044125          2015
# 3        3                   Incredibles 2  521.612833          2018
# 4        4                   The Lion King  539.238777          2019
# 5        5                   Black Panther  574.963042          2018
# 6        6          Avengers: Infinity War  584.138346          2018
# 7        7                    The Avengers  590.370689          2012
# 8        8  Jurassic World: Fallen Kingdom  670.864139          2018
# 9        9               Avengers: Endgame  686.359298          2019
# 10      10            Beauty and the Beast  691.322478          2017
#
#       budget_musd  revenue_musd
# rank
# 1           300.0   1332.698830
# 2           235.0   1405.403694
# 3           200.0   1243.225667
# 4           260.0   1662.020819
# 5           200.0   1349.926083
# 6           300.0   2052.415039
# 7           220.0   1518.815515
# 8           170.0   1310.469037
# 9           356.0   2799.439100
# 10          160.0   1266.115964

# %% [markdown]
# ## 6. Most Voted and Most Popular Movies
#
# Identify movies with the highest number of votes and highest popularity scores.

# %%
# Most voted movies
logger.info("="*60)
logger.info("TOP 10 MOST VOTED MOVIES")
logger.info("="*60)

most_voted = get_most_voted(df, top_n=10)
most_voted
# Out:
# 2025-12-10 08:47:26 - kpi_notebook - INFO - ============================================================
# 2025-12-10 08:47:26 - kpi_notebook - INFO - TOP 10 MOST VOTED MOVIES
# 2025-12-10 08:47:26 - kpi_notebook - INFO - ============================================================
#       rank                                         title  vote_count  \
# rank
# 1        1                                  The Avengers       34329
# 2        2                                        Avatar       32883
# 3        3                        Avengers: Infinity War       31188
# 4        4                             Avengers: Endgame       26978
# 5        5                                       Titanic       26519
# 6        6                       Avengers: Age of Ultron       23882
# 7        7                                 Black Panther       22980
# 8        8  Harry Potter and the Deathly Hallows: Part 2       21464
# 9        9                                Jurassic World       21127
# 10      10                  Star Wars: The Force Awakens       20104
#
#       release_year  vote_average
# rank
# 1             2012         7.870
# 2             2009         7.594
# 3             2018         8.235
# 4             2019         8.237
# 5             1997         7.903
# 6             2015         7.271
# 7             2018         7.366
# 8             2011         8.084
# 9             2015         6.699
# 10            2015         7.300

# %%
# Most popular movies
logger.info("\n" + "="*60)
logger.info("TOP 10 MOST POPULAR MOVIES")
logger.info("="*60)

most_popular = get_most_popular(df, top_n=10)
most_popular
# Out:
# 2025-12-10 08:47:26 - kpi_notebook - INFO -
# ============================================================
# 2025-12-10 08:47:26 - kpi_notebook - INFO - TOP 10 MOST POPULAR MOVIES
# 2025-12-10 08:47:26 - kpi_notebook - INFO - ============================================================
#       rank                                         title  popularity  \
# rank
# 1        1                                  The Avengers     40.3021
# 2        2                                        Avatar     38.2316
# 3        3                                       Titanic     23.4289
# 4        4                        Avengers: Infinity War     20.7267
# 5        5                                        Frozen     18.2770
# 6        6  Harry Potter and the Deathly Hallows: Part 2     17.3221
# 7        7                                     Furious 7     17.1859
# 8        8                             Avengers: Endgame     12.0878
# 9        9                       Avengers: Age of Ultron     11.1058
# 10      10                          Beauty and the Beast      9.8219
#
#       release_year  vote_average
# rank
# 1             2012         7.870
# 2             2009         7.594
# 3             1997         7.903
# 4             2018         8.235
# 5             2013         7.250
# 6             2011         8.084
# 7             2015         7.223
# 8             2019         8.237
# 9             2015         7.271
# 10            2017         6.969

# %% [markdown]
# ## 7. Highest/Lowest Rated Movies
#
# Filter to movies with at least 10 votes to ensure rating reliability.

# %%
# Highest rated movies (vote_count >= 10)
logger.info("="*60)
logger.info("TOP 10 HIGHEST RATED MOVIES (Votes >= 10)")
logger.info("="*60)

top_rated = get_top_rated(df, top_n=10)
top_rated
# Out:
# 2025-12-10 08:47:26 - kpi_notebook - INFO - ============================================================
# 2025-12-10 08:47:26 - kpi_notebook - INFO - TOP 10 HIGHEST RATED MOVIES (Votes >= 10)
# 2025-12-10 08:47:26 - kpi_notebook - INFO - ============================================================
#       rank                                         title  vote_average  \
# rank
# 1        1                             Avengers: Endgame         8.237
# 2        2                        Avengers: Infinity War         8.235
# 3        3  Harry Potter and the Deathly Hallows: Part 2         8.084
# 4        4                                       Titanic         7.903
# 5        5                                  The Avengers         7.870
# 6        6                                        Avatar         7.594
# 7        7                                 Incredibles 2         7.455
# 8        8                                 Black Panther         7.366
# 9        9                  Star Wars: The Force Awakens         7.300
# 10      10                       Avengers: Age of Ultron         7.271
#
#       release_year  vote_count
# rank
# 1             2019       26978
# 2             2018       31188
# 3             2011       21464
# 4             1997       26519
# 5             2012       34329
# 6             2009       32883
# 7             2018       13373
# 8             2018       22980
# 9             2015       20104
# 10            2015       23882

# %%
# Lowest rated movies (vote_count >= 10)
logger.info("\n" + "="*60)
logger.info("BOTTOM 10 LOWEST RATED MOVIES (Votes >= 10)")
logger.info("="*60)

bottom_rated = get_bottom_rated(df, top_n=10)
bottom_rated
# Out:
# 2025-12-10 08:47:26 - kpi_notebook - INFO -
# ============================================================
# 2025-12-10 08:47:26 - kpi_notebook - INFO - BOTTOM 10 LOWEST RATED MOVIES (Votes >= 10)
# 2025-12-10 08:47:26 - kpi_notebook - INFO - ============================================================
#       rank                           title  vote_average  release_year  \
# rank
# 1        1  Jurassic World: Fallen Kingdom         6.537          2018
# 2        2                  Jurassic World         6.699          2015
# 3        3        Star Wars: The Last Jedi         6.800          2017
# 4        4            Beauty and the Beast         6.969          2017
# 5        5                   The Lion King         7.102          2019
# 6        6                       Furious 7         7.223          2015
# 7        7                       Frozen II         7.241          2019
# 8        8                          Frozen         7.250          2013
# 9        9         Avengers: Age of Ultron         7.271          2015
# 10      10    Star Wars: The Force Awakens         7.300          2015
#
#       vote_count
# rank
# 1          12413
# 2          21127
# 3          15928
# 4          15835
# 5          10571
# 6          11035
# 7          10078
# 8          17188
# 9          23882
# 10         20104

# %% [markdown]
# ## 8. Advanced Movie Search Queries
#
# Execute complex multi-criteria searches.
#
# ### Search 1: Best-Rated Science Fiction Action Movies with Bruce Willis
#
# Find Sci-Fi Action movies starring Bruce Willis, sorted by rating (highest to lowest).

# %%
# Search 1: Bruce Willis in Sci-Fi Action
logger.info("="*60)
logger.info("SEARCH 1: Sci-Fi Action Movies with Bruce Willis")
logger.info("="*60)

search1_results = search_scifi_action_bruce_willis(df)
logger.info(f"Found {len(search1_results)} movies")
search1_results
# Out:
# 2025-12-10 08:47:26 - kpi_notebook - INFO - ============================================================
# 2025-12-10 08:47:26 - kpi_notebook - INFO - SEARCH 1: Sci-Fi Action Movies with Bruce Willis
# 2025-12-10 08:47:26 - kpi_notebook - INFO - ============================================================
# 2025-12-10 08:47:26 - kpi_notebook - INFO - Found 0 movies
# Empty DataFrame
# Columns: [title, vote_average, vote_count, genres, director, revenue_musd]
# Index: []

# %% [markdown]
# ### Search 2: Uma Thurman + Quentin Tarantino Movies
#
# Find movies starring Uma Thurman, directed by Quentin Tarantino (sorted by runtime - shortest to longest).

# %%
# Search 2: Uma Thurman directed by Quentin Tarantino
logger.info("\n" + "="*60)
logger.info("SEARCH 2: Uma Thurman + Quentin Tarantino Movies")
logger.info("="*60)

search2_results = search_uma_tarantino(df)
logger.info(f"Found {len(search2_results)} movies")
search2_results
# Out:
# 2025-12-10 08:47:26 - kpi_notebook - INFO -
# ============================================================
# 2025-12-10 08:47:26 - kpi_notebook - INFO - SEARCH 2: Uma Thurman + Quentin Tarantino Movies
# 2025-12-10 08:47:26 - kpi_notebook - INFO - ============================================================
# 2025-12-10 08:47:26 - kpi_notebook - INFO - Found 0 movies
# Empty DataFrame
# Columns: [title, runtime, vote_average, genres, revenue_musd, budget_musd]
# Index: []

# %% [markdown]
# ## 9. Franchise vs Standalone Movie Performance
#
# Compare movies that belong to franchises/collections vs standalone films.
#
# **Metrics:**
# - Mean Revenue
# - Median ROI
# - Mean Budget
# - Mean Popularity
# - Mean Rating

# %%
# Compare franchise vs standalone
logger.info("="*60)
logger.info("FRANCHISE VS STANDALONE COMPARISON")
logger.info("="*60)

comparison = compare_franchise_vs_standalone(df)
comparison
# Out:
# 2025-12-10 08:47:26 - kpi_notebook - INFO - ============================================================
# 2025-12-10 08:47:26 - kpi_notebook - INFO - FRANCHISE VS STANDALONE COMPARISON
# 2025-12-10 08:47:26 - kpi_notebook - INFO - ============================================================
#    Movie_Type  Count  Mean_Revenue_MUSD  Median_ROI_Percent  Mean_Budget_MUSD  \
# 0  Standalone      2            1765.14              861.70             180.0
# 1   Franchise     16            1682.67              678.61             218.0
#
#    Mean_Popularity  Mean_Rating
# 0            16.63         7.44
# 1            15.00         7.39

# %% [markdown]
# ## 10. Most Successful Franchises
#
# Identify the most successful movie franchises based on various metrics.

# %%
# Top franchises by total revenue
logger.info("="*60)
logger.info("TOP 10 FRANCHISES BY TOTAL REVENUE")
logger.info("="*60)

top_franchises_revenue = get_top_franchises(df, sort_by='total_revenue', top_n=10)
top_franchises_revenue
# Out:
# 2025-12-10 08:47:26 - kpi_notebook - INFO - ============================================================
# 2025-12-10 08:47:26 - kpi_notebook - INFO - TOP 10 FRANCHISES BY TOTAL REVENUE
# 2025-12-10 08:47:26 - kpi_notebook - INFO - ============================================================
#    Rank                            Franchise  Movie_Count  Total_Budget_MUSD  \
# 0     1              The Avengers Collection            4             1111.0
# 1     2                 Star Wars Collection            2              545.0
# 2     3             Jurassic Park Collection            2              320.0
# 3     4                    Avatar Collection            1              237.0
# 4     5                    Frozen Collection            2              300.0
# 5     6    The Lion King (Reboot) Collection            1              260.0
# 6     7  The Fast and the Furious Collection            1              190.0
# 7     8             Black Panther Collection            1              200.0
# 8     9              Harry Potter Collection            1              125.0
# 9    10           The Incredibles Collection            1              200.0
#
#    Mean_Budget_MUSD  Total_Revenue_MUSD  Mean_Revenue_MUSD  Mean_Rating
# 0            277.75             7776.07            1944.02         7.90
# 1            272.50             3400.92            1700.46         7.05
# 2            160.00             2982.01            1491.00         6.62
# 3            237.00             2923.71            2923.71         7.59
# 4            150.00             2727.90            1363.95         7.25
# 5            260.00             1662.02            1662.02         7.10
# 6            190.00             1515.40            1515.40         7.22
# 7            200.00             1349.93            1349.93         7.37
# 8            125.00             1341.51            1341.51         8.08
# 9            200.00             1243.23            1243.23         7.46

# %%
# Top franchises by mean rating
logger.info("\n" + "="*60)
logger.info("TOP 10 FRANCHISES BY MEAN RATING")
logger.info("="*60)

top_franchises_rating = get_top_franchises(df, sort_by='mean_rating', top_n=10)
top_franchises_rating
# Out:
# 2025-12-10 08:47:26 - kpi_notebook - INFO -
# ============================================================
# 2025-12-10 08:47:26 - kpi_notebook - INFO - TOP 10 FRANCHISES BY MEAN RATING
# 2025-12-10 08:47:26 - kpi_notebook - INFO - ============================================================
#    Rank                            Franchise  Movie_Count  Total_Budget_MUSD  \
# 0     1              Harry Potter Collection            1              125.0
# 1     2              The Avengers Collection            4             1111.0
# 2     3                    Avatar Collection            1              237.0
# 3     4           The Incredibles Collection            1              200.0
# 4     5             Black Panther Collection            1              200.0
# 5     6                    Frozen Collection            2              300.0
# 6     7  The Fast and the Furious Collection            1              190.0
# 7     8    The Lion King (Reboot) Collection            1              260.0
# 8     9                 Star Wars Collection            2              545.0
# 9    10             Jurassic Park Collection            2              320.0
#
#    Mean_Budget_MUSD  Total_Revenue_MUSD  Mean_Revenue_MUSD  Mean_Rating
# 0            125.00             1341.51            1341.51         8.08
# 1            277.75             7776.07            1944.02         7.90
# 2            237.00             2923.71            2923.71         7.59
# 3            200.00             1243.23            1243.23         7.46
# 4            200.00             1349.93            1349.93         7.37
# 5            150.00             2727.90            1363.95         7.25
# 6            190.00             1515.40            1515.40         7.22
# 7            260.00             1662.02            1662.02         7.10
# 8            272.50             3400.92            1700.46         7.05
# 9            160.00             2982.01            1491.00         6.62

# %%
# Top franchises by movie count
logger.info("\n" + "="*60)
logger.info("TOP 10 FRANCHISES BY MOVIE COUNT")
logger.info("="*60)

top_franchises_count = get_top_franchises(df, sort_by='movie_count', top_n=10)
top_franchises_count
# Out:
# 2025-12-10 08:47:26 - kpi_notebook - INFO -
# ============================================================
# 2025-12-10 08:47:26 - kpi_notebook - INFO - TOP 10 FRANCHISES BY MOVIE COUNT
# 2025-12-10 08:47:26 - kpi_notebook - INFO - ============================================================
#    Rank                            Franchise  Movie_Count  Total_Budget_MUSD  \
# 0     1              The Avengers Collection            4             1111.0
# 1     2                 Star Wars Collection            2              545.0
# 2     3             Jurassic Park Collection            2              320.0
# 3     4                    Frozen Collection            2              300.0
# 4     5                    Avatar Collection            1              237.0
# 5     6    The Lion King (Reboot) Collection            1              260.0
# 6     7  The Fast and the Furious Collection            1              190.0
# 7     8             Black Panther Collection            1              200.0
# 8     9              Harry Potter Collection            1              125.0
# 9    10           The Incredibles Collection            1              200.0
#
#    Mean_Budget_MUSD  Total_Revenue_MUSD  Mean_Revenue_MUSD  Mean_Rating
# 0            277.75             7776.07            1944.02         7.90
# 1            272.50             3400.92            1700.46         7.05
# 2            160.00             2982.01            1491.00         6.62
# 3            150.00             2727.90            1363.95         7.25
# 4            237.00             2923.71            2923.71         7.59
# 5            260.00             1662.02            1662.02         7.10
# 6            190.00             1515.40            1515.40         7.22
# 7            200.00             1349.93            1349.93         7.37
# 8            125.00             1341.51            1341.51         8.08
# 9            200.00             1243.23            1243.23         7.46

# %% [markdown]
# ## 11. Most Successful Directors
#
# Identify the most successful directors based on various metrics.

# %%
# Top directors by total revenue
logger.info("="*60)
logger.info("TOP 10 DIRECTORS BY TOTAL REVENUE")
logger.info("="*60)

top_directors_revenue = get_top_directors(df, sort_by='total_revenue', top_n=10)
top_directors_revenue
# Out:
# 2025-12-10 08:47:27 - kpi_notebook - INFO - ============================================================
# 2025-12-10 08:47:27 - kpi_notebook - INFO - TOP 10 DIRECTORS BY TOTAL REVENUE
# 2025-12-10 08:47:27 - kpi_notebook - INFO - ============================================================
#    Rank         Director  Movie_Count  Total_Revenue_MUSD  Mean_Revenue_MUSD  \
# 0     1    James Cameron            2             5187.87            2593.93
# 1     2      Joss Whedon            2             2924.22            1462.11
# 2     3    Anthony Russo            1             2799.44            2799.44
# 3     4      J.J. Abrams            1             2068.22            2068.22
# 4     5        Joe Russo            1             2052.42            2052.42
# 5     6  Colin Trevorrow            1             1671.54            1671.54
# 6     7      Jon Favreau            1             1662.02            1662.02
# 7     8        James Wan            1             1515.40            1515.40
# 8     9     Jennifer Lee            1             1453.68            1453.68
# 9    10     Ryan Coogler            1             1349.93            1349.93
#
#    Mean_Rating
# 0         7.75
# 1         7.57
# 2         8.24
# 3         7.30
# 4         8.24
# 5         6.70
# 6         7.10
# 7         7.22
# 8         7.24
# 9         7.37

# %%
# Top directors by mean rating
logger.info("\n" + "="*60)
logger.info("TOP 10 DIRECTORS BY MEAN RATING")
logger.info("="*60)

top_directors_rating = get_top_directors(df, sort_by='mean_rating', top_n=10)
top_directors_rating
# Out:
# 2025-12-10 08:47:27 - kpi_notebook - INFO -
# ============================================================
# 2025-12-10 08:47:27 - kpi_notebook - INFO - TOP 10 DIRECTORS BY MEAN RATING
# 2025-12-10 08:47:27 - kpi_notebook - INFO - ============================================================
#    Rank       Director  Movie_Count  Total_Revenue_MUSD  Mean_Revenue_MUSD  \
# 0     1  Anthony Russo            1             2799.44            2799.44
# 1     2      Joe Russo            1             2052.42            2052.42
# 2     3    David Yates            1             1341.51            1341.51
# 3     4  James Cameron            2             5187.87            2593.93
# 4     5    Joss Whedon            2             2924.22            1462.11
# 5     6      Brad Bird            1             1243.23            1243.23
# 6     7   Ryan Coogler            1             1349.93            1349.93
# 7     8    J.J. Abrams            1             2068.22            2068.22
# 8     9     Chris Buck            1             1274.22            1274.22
# 9    10   Jennifer Lee            1             1453.68            1453.68
#
#    Mean_Rating
# 0         8.24
# 1         8.24
# 2         8.08
# 3         7.75
# 4         7.57
# 5         7.46
# 6         7.37
# 7         7.30
# 8         7.25
# 9         7.24

# %%
# Top directors by movie count
logger.info("\n" + "="*60)
logger.info("TOP 10 DIRECTORS BY MOVIE COUNT")
logger.info("="*60)

top_directors_count = get_top_directors(df, sort_by='movie_count', top_n=10)
top_directors_count
# Out:
# 2025-12-10 08:47:27 - kpi_notebook - INFO -
# ============================================================
# 2025-12-10 08:47:27 - kpi_notebook - INFO - TOP 10 DIRECTORS BY MOVIE COUNT
# 2025-12-10 08:47:27 - kpi_notebook - INFO - ============================================================
#    Rank         Director  Movie_Count  Total_Revenue_MUSD  Mean_Revenue_MUSD  \
# 0     1    James Cameron            2             5187.87            2593.93
# 1     2      Joss Whedon            2             2924.22            1462.11
# 2     3    Anthony Russo            1             2799.44            2799.44
# 3     4      J.J. Abrams            1             2068.22            2068.22
# 4     5        Joe Russo            1             2052.42            2052.42
# 5     6  Colin Trevorrow            1             1671.54            1671.54
# 6     7      Jon Favreau            1             1662.02            1662.02
# 7     8        James Wan            1             1515.40            1515.40
# 8     9     Jennifer Lee            1             1453.68            1453.68
# 9    10     Ryan Coogler            1             1349.93            1349.93
#
#    Mean_Rating
# 0         7.75
# 1         7.57
# 2         8.24
# 3         7.30
# 4         8.24
# 5         6.70
# 6         7.10
# 7         7.22
# 8         7.24
# 9         7.37
